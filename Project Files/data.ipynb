# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("new_oelp_dataset.csv",parse_dates=['DATEPRD'])

# %%
df.shape
# Out:
# (15634, 15)

# %%
df.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME   X1        Y      X3       X4   X5       X6  \
# 0 2014-04-07         15/9-F-1 C  0.0    0.000   0.000    0.000  0.0  0.00000
# 1 2014-04-08         15/9-F-1 C  0.0      NaN     NaN      NaN  0.0  1.00306
# 2 2014-04-09         15/9-F-1 C  0.0      NaN     NaN      NaN  0.0  0.97901
# 3 2014-04-10         15/9-F-1 C  0.0      NaN     NaN      NaN  0.0  0.54576
# 4 2014-04-11         15/9-F-1 C  0.0  310.376  96.876  277.278  0.0  1.21599
#
#        x7     X8      X9  X10 X11  X12  X13
# 0   0.000   0.00   0.000  0.0   0  0.0  NaN
# 1   0.000   0.00   0.000  0.0   0  0.0  NaN
# 2   0.000   0.00   0.000  0.0   0  0.0  NaN
# 3   0.000   0.00   0.000  0.0   0  0.0  NaN
# 4  33.098  10.48  33.072  0.0   0  0.0  NaN

# %%
df.X11 = df.X11.str.replace('[^0-9]', '').astype(dtype=np.float64)
# Out:
# <ipython-input-33-0211859b1396>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.X11 = df.X11.str.replace('[^0-9]', '').astype(dtype=np.float64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15634 entries, 0 to 15633
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DATEPRD             15634 non-null  datetime64[ns]
#  1   NPD_WELL_BORE_NAME  15634 non-null  object
#  2   X1                  15349 non-null  float64
#  3   Y                   8980 non-null   float64
#  4   X3                  8980 non-null   float64
#  5   X4                  8980 non-null   float64
#  6   X5                  7890 non-null   float64
#  7   X6                  8919 non-null   float64
#  8   x7                  9155 non-null   float64
#  9   X8                  9146 non-null   float64
#  10  X9                  15340 non-null  float64
#  11  X10                 9161 non-null   float64
#  12  X11                 9161 non-null   float64
#  13  X12                 9161 non-null   float64
#  14  X13                 5706 non-null   float64
# ...

# %%
df.NPD_WELL_BORE_NAME.value_counts()
# Out:
# 15/9-F-4       3327
# 15/9-F-5       3306
# 15/9-F-12      3056
# 15/9-F-14      3056
# 15/9-F-11      1165
# 15/9-F-15 D     978
# 15/9-F-1 C      746
# Name: NPD_WELL_BORE_NAME, dtype: int64

# %%
well_1 = df.loc[df.NPD_WELL_BORE_NAME=='15/9-F-1 C']

# %%
well_1.shape
# Out:
# (746, 15)

# %%
well_1.tail()
# Out:
#        DATEPRD NPD_WELL_BORE_NAME   X1        Y       X3       X4   X5  \
# 741 2016-04-17         15/9-F-1 C  0.0  270.268  101.198  263.770  NaN
# 742 2016-04-18         15/9-F-1 C  0.0  276.869  101.231  263.155  NaN
# 743 2016-04-19         15/9-F-1 C  0.0  282.105  101.178  273.530  NaN
# 744 2016-04-20         15/9-F-1 C  0.0  285.096  101.131  266.816  NaN
# 745 2016-04-21         15/9-F-1 C  0.0    0.000    0.000    0.000  0.0
#
#           X6      x7      X8     X9  X10  X11  X12  X13
# 741  0.00000   6.498   9.802  2.645  0.0  0.0  0.0  NaN
# 742  0.00000  13.714  11.742  4.120  0.0  0.0  0.0  NaN
# 743  0.26519   8.576  10.119  1.866  0.0  0.0  0.0  NaN
# 744  0.00000  18.280   9.872  7.414  0.0  0.0  0.0  NaN
# 745  0.00000   0.000   0.000  0.000  0.0  0.0  0.0  NaN

# %%
well_1.DATEPRD.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
well_2 = df.loc[df.NPD_WELL_BORE_NAME=='15/9-F-15 D']

# %%
well_2.shape
# Out:
# (978, 15)

# %%
well_2.DATEPRD.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
well_3 = df.loc[df.NPD_WELL_BORE_NAME=='15/9-F-11']

# %%
well_3.shape
# Out:
# (1165, 15)

# %%
well_3.DATEPRD.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
well_4 = df.loc[df.NPD_WELL_BORE_NAME=='15/9-F-14']

# %%
well_4.shape
# Out:
# (3056, 15)

# %%
well_4.DATEPRD.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
well_5 = df.loc[df.NPD_WELL_BORE_NAME=='15/9-F-12']

# %%
well_5.shape
# Out:
# (3056, 15)

# %%
well_5.DATEPRD.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
merged = pd.merge(well_1,well_2,suffixes=("_a","_b"),on="DATEPRD")

# %%
merged.shape
# Out:
# (746, 29)

# %%
merged.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME_a  X1_a      Y_a    X3_a     X4_a  X5_a  \
# 0 2014-04-07           15/9-F-1 C   0.0    0.000   0.000    0.000   0.0
# 1 2014-04-08           15/9-F-1 C   0.0      NaN     NaN      NaN   0.0
# 2 2014-04-09           15/9-F-1 C   0.0      NaN     NaN      NaN   0.0
# 3 2014-04-10           15/9-F-1 C   0.0      NaN     NaN      NaN   0.0
# 4 2014-04-11           15/9-F-1 C   0.0  310.376  96.876  277.278   0.0
#
#       X6_a    x7_a   X8_a  ...     X4_b    X5_b      X6_b    x7_b    X8_b  \
# 0  0.00000   0.000   0.00  ...  159.693  15.250  10.02346  47.279  26.436
# 1  1.00306   0.000   0.00  ...  154.748  22.064  12.62097  45.161  29.903
# 2  0.97901   0.000   0.00  ...  154.718  22.807  12.45271  45.388  32.299
# 3  0.54576   0.000   0.00  ...  156.612  20.368  11.13430  46.522  29.688
# 4  1.21599  33.098  10.48  ...  154.657  22.626  12.33667  45.422  31.534
#
#      X9_b  X10_b    X11_b  X12_b  X13_b
# 0  18.536  208.0  32572.0    0.0    NaN
# ...

# %%
merged.shape
# Out:
# (746, 29)

# %%
merged_2 = pd.merge(well_1,well_3,suffixes=("_a2","_c"),on="DATEPRD")

# %%
merged_2.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME_a2  X1_a2     Y_a2   X3_a2    X4_a2  X5_a2  \
# 0 2014-04-07            15/9-F-1 C    0.0    0.000   0.000    0.000    0.0
# 1 2014-04-08            15/9-F-1 C    0.0      NaN     NaN      NaN    0.0
# 2 2014-04-09            15/9-F-1 C    0.0      NaN     NaN      NaN    0.0
# 3 2014-04-10            15/9-F-1 C    0.0      NaN     NaN      NaN    0.0
# 4 2014-04-11            15/9-F-1 C    0.0  310.376  96.876  277.278    0.0
#
#      X6_a2   x7_a2  X8_a2  ...     X4_c    X5_c      X6_c    x7_c    X8_c  \
# 0  0.00000   0.000   0.00  ...  177.175   3.684   1.84062  81.893  45.603
# 1  1.00306   0.000   0.00  ...  172.530  18.535  10.36859  70.579  61.209
# 2  0.97901   0.000   0.00  ...  167.133  25.393  11.18810  68.020  66.582
# 3  0.54576   0.000   0.00  ...  171.515  22.463   9.23766  72.626  60.914
# 4  1.21599  33.098  10.48  ...  166.817  26.863  11.27512  68.491  65.735
#
#      X9_c   X10_c     X11_c  X12_c  X13_c
# ...

# %%
merged_2.shape
# Out:
# (746, 29)

# %%
merged_3 = pd.merge(well_1,well_4,suffixes=("_a3","_d"),on="DATEPRD")

# %%
merged_3.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME_a3  X1_a3     Y_a3   X3_a3    X4_a3  X5_a3  \
# 0 2014-04-07            15/9-F-1 C    0.0    0.000   0.000    0.000    0.0
# 1 2014-04-08            15/9-F-1 C    0.0      NaN     NaN      NaN    0.0
# 2 2014-04-09            15/9-F-1 C    0.0      NaN     NaN      NaN    0.0
# 3 2014-04-10            15/9-F-1 C    0.0      NaN     NaN      NaN    0.0
# 4 2014-04-11            15/9-F-1 C    0.0  310.376  96.876  277.278    0.0
#
#      X6_a3   x7_a3  X8_a3  ...     X4_d    X5_d       X6_d    x7_d    X8_d  \
# 0  0.00000   0.000   0.00  ...  225.575  19.539   59.63114  35.110  83.267
# 1  1.00306   0.000   0.00  ...  223.432  20.939  100.00000  32.239  87.992
# 2  0.97901   0.000   0.00  ...  223.536  21.103  100.00000  32.390  88.304
# 3  0.54576   0.000   0.00  ...  226.000  19.713   60.39449  35.779  84.243
# 4  1.21599  33.098  10.48  ...  223.400  20.956  100.00000  32.517  87.932
#
#     X9_d  X10_d    X11_d   X12_d  X13_d
# ...

# %%
merged_3.shape
# Out:
# (746, 29)

# %%
merged_4 = pd.merge(well_1,well_5,suffixes=('_a4','_e'),on="DATEPRD")

# %%
merged_4.shape
# Out:
# (746, 29)

# %%
merged_4.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME_a4  X1_a4     Y_a4   X3_a4    X4_a4  X5_a4  \
# 0 2014-04-07            15/9-F-1 C    0.0    0.000   0.000    0.000    0.0
# 1 2014-04-08            15/9-F-1 C    0.0      NaN     NaN      NaN    0.0
# 2 2014-04-09            15/9-F-1 C    0.0      NaN     NaN      NaN    0.0
# 3 2014-04-10            15/9-F-1 C    0.0      NaN     NaN      NaN    0.0
# 4 2014-04-11            15/9-F-1 C    0.0  310.376  96.876  277.278    0.0
#
#      X6_a4   x7_a4  X8_a4  ...    X4_e    X5_e      X6_e    x7_e    X8_e  \
# 0  0.00000   0.000   0.00  ...  34.457  14.452  10.99470  34.457  82.160
# 1  1.00306   0.000   0.00  ...  31.726  19.060  99.90160  31.726  90.142
# 2  0.97901   0.000   0.00  ...  32.148  19.894  99.96397  32.148  90.756
# 3  0.54576   0.000   0.00  ...  32.314  19.919  82.83643  32.314  90.359
# 4  1.21599  33.098  10.48  ...  32.410  20.053  99.95080  32.410  90.306
#
#     X9_e  X10_e    X11_e   X12_e  X13_e
# ...

# %%
merged_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 746 entries, 0 to 745
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATEPRD                746 non-null    datetime64[ns]
#  1   NPD_WELL_BORE_NAME_a2  746 non-null    object
#  2   X1_a2                  746 non-null    float64
#  3   Y_a2                   743 non-null    float64
#  4   X3_a2                  743 non-null    float64
#  5   X4_a2                  743 non-null    float64
#  6   X5_a2                  17 non-null     float64
#  7   X6_a2                  746 non-null    float64
#  8   x7_a2                  746 non-null    float64
#  9   X8_a2                  746 non-null    float64
#  10  X9_a2                  746 non-null    float64
#  11  X10_a2                 746 non-null    float64
#  12  X11_a2                 746 non-null    float64
#  13  X12_a2                 746 non-null    float64
# ...

# %%
new = pd.DataFrame(well_1.columns+'_a4',columns=["1"])

# %%
new.head()
# Out:
#                        1
# 0             DATEPRD_a4
# 1  NPD_WELL_BORE_NAME_a4
# 2                  X1_a4
# 3                   Y_a4
# 4                  X3_a4

# %%
new.drop(index=0,axis=0,inplace=True)

# %%
new.head()
# Out:
#                        1
# 1  NPD_WELL_BORE_NAME_a4
# 2                  X1_a4
# 3                   Y_a4
# 4                  X3_a4
# 5                  X4_a4

# %%
merged_2.drop(new["1"],axis=1,inplace=True)

# %%
merged_2.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME_c   X1_c      Y_c     X3_c     X4_c    X5_c  \
# 0 2014-04-07            15/9-F-11   3.50  259.067  104.969  177.175   3.684
# 1 2014-04-08            15/9-F-11  24.00  243.109  105.825  172.530  18.535
# 2 2014-04-09            15/9-F-11  24.00  235.152  106.201  167.133  25.393
# 3 2014-04-10            15/9-F-11  21.96  244.141  106.053  171.515  22.463
# 4 2014-04-11            15/9-F-11  24.00  235.307  106.295  166.817  26.863
#
#        X6_c    x7_c    X8_c    X9_c   X10_c     X11_c  X12_c  X13_c
# 0   1.84062  81.893  45.603  53.512    53.0    8279.0    7.0    NaN
# 1  10.36859  70.579  61.209  42.146  1041.0  159740.0  125.0    NaN
# 2  11.18810  68.020  66.582  39.576  1218.0  184930.0  139.0    NaN
# 3   9.23766  72.626  60.914  44.390   985.0  160416.0  110.0    NaN
# 4  11.27512  68.491  65.735  39.954  1259.0  190660.0  141.0    NaN

# %%
merged_3.drop(new["1"],axis=1,inplace=True)

# %%
merged_3.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME_d   X1_d      Y_d     X3_d     X4_d    X5_d  \
# 0 2014-04-07            15/9-F-14  18.94  260.684   99.985  225.575  19.539
# 1 2014-04-08            15/9-F-14  24.00  255.671  100.006  223.432  20.939
# 2 2014-04-09            15/9-F-14  24.00  255.926  100.024  223.536  21.103
# 3 2014-04-10            15/9-F-14  16.29  261.779   99.956  226.000  19.713
# 4 2014-04-11            15/9-F-14  24.00  255.917   99.988  223.400  20.956
#
#         X6_d    x7_d    X8_d   X9_d  X10_d    X11_d   X12_d  X13_d
# 0   59.63114  35.110  83.267  6.111  428.0  64858.0  3102.0    NaN
# 1  100.00000  32.239  87.992  2.589  544.0  80802.0  3615.0    NaN
# 2  100.00000  32.390  88.304  2.529  574.0  84290.0  3612.0    NaN
# 3   60.39449  35.779  84.243  6.273  294.0  46395.0  1824.0    NaN
# 4  100.00000  32.517  87.932  2.810  586.0  85785.0  3625.0    NaN

# %%
merged_4.drop(new["1"],axis=1,inplace=True)

# %%
merged_4.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME_e   X1_e  Y_e  X3_e    X4_e    X5_e      X6_e  \
# 0 2014-04-07            15/9-F-12   5.00  0.0   0.0  34.457  14.452  10.99470
# 1 2014-04-08            15/9-F-12  24.00  0.0   0.0  31.726  19.060  99.90160
# 2 2014-04-09            15/9-F-12  24.00  0.0   0.0  32.148  19.894  99.96397
# 3 2014-04-10            15/9-F-12  21.96  0.0   0.0  32.314  19.919  82.83643
# 4 2014-04-11            15/9-F-12  24.00  0.0   0.0  32.410  20.053  99.95080
#
#      x7_e    X8_e   X9_e  X10_e    X11_e   X12_e  X13_e
# 0  34.457  82.160  6.089   12.0   1948.0   352.0    NaN
# 1  31.726  90.142  3.163  199.0  30469.0  5154.0    NaN
# 2  32.148  90.756  3.558  209.0  31793.0  5151.0    NaN
# 3  32.314  90.359  3.893  202.0  32970.0  4901.0    NaN
# 4  32.410  90.306  3.784  214.0  32356.0  5169.0    NaN

# %%
new = merged.merge(merged_2).merge(merged_3).merge(merged_4)

# %%
new.shape
# Out:
# (746, 71)

# %%
new.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME_a  X1_a      Y_a    X3_a     X4_a  X5_a  \
# 0 2014-04-07           15/9-F-1 C   0.0    0.000   0.000    0.000   0.0
# 1 2014-04-08           15/9-F-1 C   0.0      NaN     NaN      NaN   0.0
# 2 2014-04-09           15/9-F-1 C   0.0      NaN     NaN      NaN   0.0
# 3 2014-04-10           15/9-F-1 C   0.0      NaN     NaN      NaN   0.0
# 4 2014-04-11           15/9-F-1 C   0.0  310.376  96.876  277.278   0.0
#
#       X6_a    x7_a   X8_a  ...    X4_e    X5_e      X6_e    x7_e    X8_e  \
# 0  0.00000   0.000   0.00  ...  34.457  14.452  10.99470  34.457  82.160
# 1  1.00306   0.000   0.00  ...  31.726  19.060  99.90160  31.726  90.142
# 2  0.97901   0.000   0.00  ...  32.148  19.894  99.96397  32.148  90.756
# 3  0.54576   0.000   0.00  ...  32.314  19.919  82.83643  32.314  90.359
# 4  1.21599  33.098  10.48  ...  32.410  20.053  99.95080  32.410  90.306
#
#     X9_e  X10_e    X11_e   X12_e  X13_e
# 0  6.089   12.0   1948.0   352.0    NaN
# ...

# %%
# new.to_csv("final_merged_df.csv",index=False)

# %%
plt.style.use("seaborn-deep")
plot_1.plot(kind='bar',figsize=(17,10))
plt.xticks(fontsize=10)
plt.xlabel("Features",fontsize=15)
plt.ylabel("NA value",fontsize=15);

# %%
new.drop(["NPD_WELL_BORE_NAME_a","NPD_WELL_BORE_NAME_b","NPD_WELL_BORE_NAME_c","NPD_WELL_BORE_NAME_d","NPD_WELL_BORE_NAME_e","X5_a","X13_a","X13_b","X13_c","X13_d","X13_e"],axis=1,inplace=True)

# %%
new.dropna(inplace=True)

# %%
# new.to_csv("final_merged_dropped.csv",index=False)

# %%
inj_1 = df.loc[df.NPD_WELL_BORE_NAME=='15/9-F-5']

# %%
inj_2 = df.loc[df.NPD_WELL_BORE_NAME=='15/9-F-4']

# %%
inj_1.head()
# Out:
#          DATEPRD NPD_WELL_BORE_NAME  X1   Y  X3  X4  X5  X6  x7  X8  X9  X10  \
# 12328 2007-09-01           15/9-F-5 NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN
# 12329 2007-09-02           15/9-F-5 NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN
# 12330 2007-09-03           15/9-F-5 NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN
# 12331 2007-09-04           15/9-F-5 NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN
# 12332 2007-09-05           15/9-F-5 NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN
#
#        X11  X12  X13
# 12328  NaN  NaN  NaN
# 12329  NaN  NaN  NaN
# 12330  NaN  NaN  NaN
# 12331  NaN  NaN  NaN
# 12332  NaN  NaN  NaN

# %%
inj_1.DATEPRD.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
inj_2.DATEPRD.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("seaborn-deep")
inj_2.isna().sum().plot(kind='bar',figsize=(15,8))
plt.xticks(fontsize=10)
plt.xlabel("Features",fontsize=15)
plt.ylabel("NA value",fontsize=15);

# %%
plt.style.use("seaborn-deep")
inj_1.isna().sum().plot(kind='bar',figsize=(15,8))
plt.xticks(fontsize=10)
plt.xlabel("Features",fontsize=15)
plt.ylabel("NA value",fontsize=15);

# %%
inj_1.loc[inj_1.DATEPRD>='2014-04-07']
# Out:
#          DATEPRD NPD_WELL_BORE_NAME     X1   Y  X3  X4     X5       X6     x7  \
# 14738 2014-04-07           15/9-F-5  21.00 NaN NaN NaN    NaN      NaN    NaN
# 14739 2014-04-08           15/9-F-5  24.00 NaN NaN NaN    NaN      NaN    NaN
# 14740 2014-04-09           15/9-F-5  24.00 NaN NaN NaN    NaN      NaN    NaN
# 14741 2014-04-10           15/9-F-5  20.54 NaN NaN NaN    NaN      NaN    NaN
# 14742 2014-04-11           15/9-F-5  24.00 NaN NaN NaN    NaN      NaN    NaN
# ...          ...                ...    ...  ..  ..  ..    ...      ...    ...
# 15629 2016-09-14           15/9-F-5   0.00 NaN NaN NaN  0.273  0.63609  0.078
# 15630 2016-09-15           15/9-F-5   0.00 NaN NaN NaN  0.287  0.67079  0.085
# 15631 2016-09-16           15/9-F-5   0.00 NaN NaN NaN  0.286  0.66439  0.085
# 15632 2016-09-17           15/9-F-5   0.00 NaN NaN NaN  0.272  0.62466  0.075
# 15633 2016-09-18           15/9-F-5   0.00 NaN NaN NaN    NaN      NaN    NaN
#
# ...

# %%
merge_1 = well_1.merge(inj_1,on="DATEPRD",suffixes=("_x","_y"))

# %%
merge_1
# Out:
#        DATEPRD NPD_WELL_BORE_NAME_x  X1_x      Y_x     X3_x     X4_x  X5_x  \
# 0   2014-04-07           15/9-F-1 C   0.0    0.000    0.000    0.000   0.0
# 1   2014-04-08           15/9-F-1 C   0.0      NaN      NaN      NaN   0.0
# 2   2014-04-09           15/9-F-1 C   0.0      NaN      NaN      NaN   0.0
# 3   2014-04-10           15/9-F-1 C   0.0      NaN      NaN      NaN   0.0
# 4   2014-04-11           15/9-F-1 C   0.0  310.376   96.876  277.278   0.0
# ..         ...                  ...   ...      ...      ...      ...   ...
# 741 2016-04-17           15/9-F-1 C   0.0  270.268  101.198  263.770   NaN
# 742 2016-04-18           15/9-F-1 C   0.0  276.869  101.231  263.155   NaN
# 743 2016-04-19           15/9-F-1 C   0.0  282.105  101.178  273.530   NaN
# 744 2016-04-20           15/9-F-1 C   0.0  285.096  101.131  266.816   NaN
# 745 2016-04-21           15/9-F-1 C   0.0    0.000    0.000    0.000   0.0
#
# ...

# %%
merge_2 = well_1.merge(inj_2,on="DATEPRD",suffixes=("_x","_z"))

# %%
merge_2
# Out:
#        DATEPRD NPD_WELL_BORE_NAME_x  X1_x      Y_x     X3_x     X4_x  X5_x  \
# 0   2014-04-07           15/9-F-1 C   0.0    0.000    0.000    0.000   0.0
# 1   2014-04-08           15/9-F-1 C   0.0      NaN      NaN      NaN   0.0
# 2   2014-04-09           15/9-F-1 C   0.0      NaN      NaN      NaN   0.0
# 3   2014-04-10           15/9-F-1 C   0.0      NaN      NaN      NaN   0.0
# 4   2014-04-11           15/9-F-1 C   0.0  310.376   96.876  277.278   0.0
# ..         ...                  ...   ...      ...      ...      ...   ...
# 741 2016-04-17           15/9-F-1 C   0.0  270.268  101.198  263.770   NaN
# 742 2016-04-18           15/9-F-1 C   0.0  276.869  101.231  263.155   NaN
# 743 2016-04-19           15/9-F-1 C   0.0  282.105  101.178  273.530   NaN
# 744 2016-04-20           15/9-F-1 C   0.0  285.096  101.131  266.816   NaN
# 745 2016-04-21           15/9-F-1 C   0.0    0.000    0.000    0.000   0.0
#
# ...

# %%
drop = pd.DataFrame(well_1.columns+"_z")

# %%
drop
# Out:
#                        0
# 0              DATEPRD_z
# 1   NPD_WELL_BORE_NAME_z
# 2                   X1_z
# 3                    Y_z
# 4                   X3_z
# 5                   X4_z
# 6                   X5_z
# 7                   X6_z
# 8                   x7_z
# 9                   X8_z
# 10                  X9_z
# 11                 X10_z
# 12                 X11_z
# 13                 X12_z
# 14                 X13_z

# %%
drop.drop(index=[0,2,10,14],inplace=True)

# %%
drop
# Out:
#                        0
# 1   NPD_WELL_BORE_NAME_z
# 3                    Y_z
# 4                   X3_z
# 5                   X4_z
# 6                   X5_z
# 7                   X6_z
# 8                   x7_z
# 9                   X8_z
# 11                 X10_z
# 12                 X11_z
# 13                 X12_z

# %%
# merge_2.drop(drop[0],axis=1,inplace=True)

# %%
# merge_1.drop(drop[0],axis=1,inplace=True)

# %%
plt.style.use("seaborn-deep")
merge_1.isna().sum().plot(kind='bar',figsize=(15,8))
plt.xticks(fontsize=10)
plt.xlabel("Features",fontsize=15)
plt.ylabel("NA value",fontsize=15);

# %%
plt.style.use("seaborn-deep")
merge_2.isna().sum().plot(kind='bar',figsize=(15,8))
plt.xticks(fontsize=10)
plt.xlabel("Features",fontsize=15)
plt.ylabel("NA value",fontsize=15);

# %%
final_df = new.merge(merge_1).merge(merge_2)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 743 entries, 0 to 742
# Data columns (total 88 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DATEPRD               743 non-null    datetime64[ns]
#  1   X1_a                  743 non-null    float64
#  2   Y_a                   743 non-null    float64
#  3   X3_a                  743 non-null    float64
#  4   X4_a                  743 non-null    float64
#  5   X6_a                  743 non-null    float64
#  6   x7_a                  743 non-null    float64
#  7   X8_a                  743 non-null    float64
#  8   X9_a                  743 non-null    float64
#  9   X10_a                 743 non-null    float64
#  10  X11_a                 743 non-null    float64
#  11  X12_a                 743 non-null    float64
#  12  X1_b                  743 non-null    float64
#  13  Y_b                   743 non-null    float64
# ...

# %%
# final_df.drop(drop[0],axis=1,inplace=True)

# %%
final_df.drop(drop[0],axis=1,inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 743 entries, 0 to 742
# Data columns (total 66 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATEPRD  743 non-null    datetime64[ns]
#  1   X1_a     743 non-null    float64
#  2   Y_a      743 non-null    float64
#  3   X3_a     743 non-null    float64
#  4   X4_a     743 non-null    float64
#  5   X6_a     743 non-null    float64
#  6   x7_a     743 non-null    float64
#  7   X8_a     743 non-null    float64
#  8   X9_a     743 non-null    float64
#  9   X10_a    743 non-null    float64
#  10  X11_a    743 non-null    float64
#  11  X12_a    743 non-null    float64
#  12  X1_b     743 non-null    float64
#  13  Y_b      743 non-null    float64
#  14  X3_b     743 non-null    float64
#  15  X4_b     743 non-null    float64
#  16  X5_b     743 non-null    float64
#  17  X6_b     743 non-null    float64
#  18  x7_b     743 non-null    float64
#  19  X8_b     743 non-null    float64
# ...

# %%
final_df.isna().sum().plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
final_df.dropna(inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 732 entries, 0 to 731
# Data columns (total 66 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATEPRD  732 non-null    datetime64[ns]
#  1   X1_a     732 non-null    float64
#  2   Y_a      732 non-null    float64
#  3   X3_a     732 non-null    float64
#  4   X4_a     732 non-null    float64
#  5   X6_a     732 non-null    float64
#  6   x7_a     732 non-null    float64
#  7   X8_a     732 non-null    float64
#  8   X9_a     732 non-null    float64
#  9   X10_a    732 non-null    float64
#  10  X11_a    732 non-null    float64
#  11  X12_a    732 non-null    float64
#  12  X1_b     732 non-null    float64
#  13  Y_b      732 non-null    float64
#  14  X3_b     732 non-null    float64
#  15  X4_b     732 non-null    float64
#  16  X5_b     732 non-null    float64
#  17  X6_b     732 non-null    float64
#  18  x7_b     732 non-null    float64
#  19  X8_b     732 non-null    float64
# ...

# %%
final_df.columns
# Out:
# Index(['DATEPRD', 'X1_a', 'Y_a', 'X3_a', 'X4_a', 'X6_a', 'x7_a', 'X8_a',
#        'X9_a', 'X10_a', 'X11_a', 'X12_a', 'X1_b', 'Y_b', 'X3_b', 'X4_b',
#        'X5_b', 'X6_b', 'x7_b', 'X8_b', 'X9_b', 'X10_b', 'X11_b', 'X12_b',
#        'X1_c', 'Y_c', 'X3_c', 'X4_c', 'X5_c', 'X6_c', 'x7_c', 'X8_c', 'X9_c',
#        'X10_c', 'X11_c', 'X12_c', 'X1_d', 'Y_d', 'X3_d', 'X4_d', 'X5_d',
#        'X6_d', 'x7_d', 'X8_d', 'X9_d', 'X10_d', 'X11_d', 'X12_d', 'X1_e',
#        'Y_e', 'X3_e', 'X4_e', 'X5_e', 'X6_e', 'x7_e', 'X8_e', 'X9_e', 'X10_e',
#        'X11_e', 'X12_e', 'X1_y', 'X9_y', 'X13_y', 'X1_z', 'X9_z', 'X13_z'],
#       dtype='object')

# %%
# final_df.to_csv("prod_inje_merge_drop.csv",index=False)

# %%
import sys
if not 'Informer2020' in sys.path:
    sys.path += ['Informer2020']

# %%
data = pd.read_csv(r"C:\Users\OMS\Downloads\ETTh1.csv")

# %%
data.shape
# Out:
# (17420, 8)

# %%
data.head()
# Out:
#                   date   HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# 0  2016-07-01 00:00:00  5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 1  2016-07-01 01:00:00  5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2  2016-07-01 02:00:00  5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 3  2016-07-01 03:00:00  5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 4  2016-07-01 04:00:00  5.358  1.942  1.492  0.462  3.868  1.279  21.948000
